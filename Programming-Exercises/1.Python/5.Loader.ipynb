# %%
# %%shell
# gdown -q 1VEG0qsiD5CZqyKSv5k6TceJbLOCt2yp7
# echo 'download: done => file: animals.zip'
# rm -rf ./animals/
# unzip -q animals.zip
# echo 'Data files in: /content/animals/'
# Out:
# download: done => file: animals.zip
# Data files in: /content/animals/

# %%
class DataLoader(object):
  def __init__(self):
    self.L = [1, 2, 3, 4, 5]
    self.idx = 0

  def __iter__(self):
    return self

  def __next__(self):
    if self.idx >= len(self.L):
      raise StopIteration
    v = self.L[self.idx]
    self.idx += 1
    return v

# %%
loader = DataLoader()
for i in loader:
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
L = [1,2,4, 5]
for v in L:
  print(v)
# Out:
# 1
# 2
# 4
# 5

# %%
class Module(object):
  def __init__(self):
    pass

  def __call__(self, X):
    return self.forward(X)

  def forward(self, X):
    raise NotImplementedError


class Model(Module):
  def __init__(self):
    super().__init__()

  def forward(self, X):
    print(f"{X}")
    return X**2

# %%
model = Model()
X = 10
Y = model(X)
print(Y)
# Out:
# 10
# 100

# %%
class Point(object):
  def __init__(self, x:float, y:float, z:float):
    self.x = x
    self.y = y
    self.z = z

  def __str__(self):
    return f"({self.x: 6.2f}, {self.y: 6.2f}, {self.z: 6.2f})"

  def __repr__(self):
    return f"({self.x: 6.2f}, {self.y: 6.2f}, {self.z: 6.2f})"

  def __add__(self, other):
    return Point(self.x + other.x, self.y + other.y, self.z + other.z)

  def A2B(A, B):
    return Vector(B.x - A.x, B.y - A.y, B.z - A.z)


class Vector(object):
  def __init__(self, x:float, y:float, z:float):
    self.x = x
    self.y = y
    self.z = z

  def __str__(self):
   return f"({self.x: 6.2f}, {self.y: 6.2f}, {self.z: 6.2f})"

  def __repr__(self):
    return self.__str__()

  def __add__(self, other):
    return Vector(self.x + other.x, self.y + other.y, self.z + other.z)

  def length(self):
    return (self.x**2 + self.y**2 + self.z**2)**0.5

# %%
v = Vector(1.5, 2.0, 4.5)
v.length()
q = Vector(1.0, 1.0, 1.0)
print(v + q)
# Out:
# (  2.50,   3.00,   5.50)

# %%
P = Point(1, 2, 3)
Q = Point(2, 5, 7)
a = Point.A2B(P, Q)
print(a)
# Out:
# (  1.00,   3.00,   4.00)

# %%
import os
import glob
import functools as F
import random

class DataLoader(object):
  def __init__(self, path:str, batch_size=5):
    # YOUR CODE IS HERE
    self.prepare()

  def prepare(self):
    # YOUR CODE IS HERE
    pass

  def __iter__(self):
    # YOUR CODE IS HERE
    return self

  def __next__(self):
    # YOUR CODE IS HERE
    pass

# %%
loader = DataLoader("./animals/")
for idx, (files, labels) in enumerate(loader):
  print(f"batch: {idx}")
  print("files: ", files)
  print("labels: ", labels)
# Out:
# batch: 0
# files:  ['./animals/dog/dog-5.jpeg', './animals/dog/dog-3.jpg', './animals/chicken/c2.jpg', './animals/horse/horse-2.jpg', './animals/dog/dog-7.jpg']
# labels:  ['dog', 'dog', 'chicken', 'horse', 'dog']
# batch: 1
# files:  ['./animals/chicken/c4.jpeg', './animals/horse/horse-3.jpeg', './animals/dog/dog-2.jpg', './animals/goose/g2.jpg', './animals/cat/cat-2.jpg']
# labels:  ['chicken', 'horse', 'dog', 'goose', 'cat']
# batch: 2
# files:  ['./animals/horse/horse-1.jpg', './animals/chicken/c5.jpg', './animals/cat/cat-1.jpg', './animals/goose/g3.jpg', './animals/cat/cat-4.jpg']
# labels:  ['horse', 'chicken', 'cat', 'goose', 'cat']
# batch: 3
# files:  ['./animals/dog/dog-6.jpg', './animals/chicken/c1.jpg', './animals/cat/cat-6.jpg', './animals/horse/horse-4.jpg', './animals/dog/dog-1.jpg']
# labels:  ['dog', 'chicken', 'cat', 'horse', 'dog']
# batch: 4
# files:  ['./animals/chicken/c3.jpg', './animals/cat/cat-5.jpeg', './animals/cat/cat-3.jpeg', './animals/horse/horse-5.jpg', './animals/dog/dog-4.jpeg']
# labels:  ['chicken', 'cat', 'cat', 'horse', 'dog']
# batch: 5
# files:  ['./animals/goose/g1.jpg']
# labels:  ['goose']

# %%
"""
load_data: implement it as a generator
"""
def load_data(path_to_data:str, batch_size=5):
    # YOUR CODE IS HERE

# %%
loader = load_data("./animals/")
for files, labels in loader:
  print(files)
  print(labels)
# Out:
# ['./animals/dog/dog-1.jpg', './animals/dog/dog-7.jpg', './animals/dog/dog-2.jpg', './animals/chicken/c5.jpg', './animals/chicken/c3.jpg']
# ['dog', 'dog', 'dog', 'chicken', 'chicken']
# ['./animals/cat/cat-6.jpg', './animals/goose/g2.jpg', './animals/cat/cat-2.jpg', './animals/cat/cat-3.jpeg', './animals/cat/cat-4.jpg']
# ['cat', 'goose', 'cat', 'cat', 'cat']
# ['./animals/cat/cat-1.jpg', './animals/horse/horse-5.jpg', './animals/dog/dog-4.jpeg', './animals/horse/horse-2.jpg', './animals/dog/dog-5.jpeg']
# ['cat', 'horse', 'dog', 'horse', 'dog']
# ['./animals/dog/dog-3.jpg', './animals/dog/dog-6.jpg', './animals/goose/g3.jpg', './animals/goose/g1.jpg', './animals/chicken/c2.jpg']
# ['dog', 'dog', 'goose', 'goose', 'chicken']
# ['./animals/cat/cat-5.jpeg', './animals/horse/horse-1.jpg', './animals/chicken/c4.jpeg', './animals/horse/horse-3.jpeg', './animals/chicken/c1.jpg']
# ['cat', 'horse', 'chicken', 'horse', 'chicken']
